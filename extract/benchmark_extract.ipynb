# %%
"""Điểm khởi đầu chính của ứng dụng."""

import os
import time
from datetime import datetime
import config
import text_processor
import api_handler
import entity_processor
import output_manager
import utils
from api_handler import reset_request_counter


def process_entities() -> list:
    """Main function to process all files and extract entities."""
    # Reset counters
    reset_request_counter()
    
    all_entities = []
    
    file_contents = text_processor.read_files(config.INPUT_FILES)
    
    # Tính toán tổng số window trước để ước lượng
    total_windows = 0
    for file_path, content in file_contents.items():
        if not content:
            continue
        sentences = utils.split_sentences_vietnamese(content)
        windows = text_processor.create_non_overlapping_windows(sentences, window_size=config.WINDOW_SIZE)
        total_windows += len(windows)
    
    print(f"\nTotal estimated API requests (windows): {total_windows}")
    print(f"Estimated processing time: {total_windows * config.API_DELAY_SECONDS / 60:.1f} minutes (with rate limiting)")
    print("=" * 60)
    
    current_window = 0
    
    for file_path, content in file_contents.items():
        if not content:
            continue
            
        print(f"\nProcessing {file_path}...")
        
        sentences = utils.split_sentences_vietnamese(content)
        windows = text_processor.create_non_overlapping_windows(sentences, window_size=config.WINDOW_SIZE)
        
        for window in windows:
            current_window += 1
            print(f"\n[Progress: {current_window}/{total_windows} windows]")
            print(f"  Processing window {window['window_index'] + 1}/{len(windows)} of current file")
            
            entities = api_handler.extract_entities_with_gemini(window, file_path)
            
            for entity in entities:
                similar_entity = entity_processor.find_similar_entity(entity, all_entities)
                
                if similar_entity:
                    if entity_processor.merge_entities(similar_entity, entity):
                        print(f"    Merged entity: {entity['id']}")
                else:
                    all_entities.append(entity)
                    print(f"    New entity: {entity['id']} ({entity['type']})")
    
    # Post-process all entities
    all_entities = entity_processor.post_process_entities(all_entities)
    
    # Áp dụng làm sạch cuối cùng
    all_entities = entity_processor.cleanup_entities(all_entities)
    
    return all_entities
    
    return all_entities


def main():
    """Hàm main chính."""
    print("Starting entity extraction with improved logic...")
    
    # Cấu hình API
    import google.generativeai as genai
    genai.configure(api_key=config.GOOGLE_API_KEY)
    
    # Xử lý entities
    entities = process_entities()
    
    # Lưu kết quả
    output_manager.save_entities(entities)
    
    print("Entity extraction completed.")


if __name__ == "__main__":
    main()
# Out:
# Starting entity extraction with improved logic...
#
# Total estimated API requests (windows): 189
# Estimated processing time: 22.1 minutes (with rate limiting)
# ============================================================
#
# Processing SGK/Nguồn/Chủ đề 1/Bài 1.txt...
#
# [Progress: 1/189 windows]
#   Processing window 1/10 of current file
#   [Request #1] Chủ đề 1 - Bài 1 - Window 1
#   [Request #1] Completed - Extracted 3 entities
#     New entity: Chiến tranh thế giới thứ hai (Sự kiện)
#     New entity: phe Đồng minh chống phát xít (Khái niệm)
#     New entity: Hội Quốc liên (Tổ chức)
#
# [Progress: 2/189 windows]
#   Processing window 2/10 of current file
#   [Request #2] Chủ đề 1 - Bài 1 - Window 2
#   [Request #2] Completed - Extracted 7 entities
#     New entity: Liên Xô (Quốc gia)
#     New entity: Anh (Quốc gia)
#     New entity: Liên hợp quốc (Tổ chức)
#     New entity: Tuyên bố về Liên hợp quốc (Văn kiện/Hiệp định)
#     New entity: Hội nghị Tê-hê-ran (Hội nghị)
#     New entity: Hội nghị I-an-ta (Hội nghị)
#     New entity: Hiến chương Liên hợp quốc (Văn kiện/Hiệp định)
#
# [Progress: 3/189 windows]
#   Processing window 3/10 of current file
#   [Request #3] Chủ đề 1 - Bài 1 - Window 3
#   [Request #3] Completed - Extracted 4 entities
#     Merged entity: Liên hợp quốc
#     Merged entity: Hiến chương Liên hợp quốc
#     Merged entity: Hội Quốc liên
#     Merged entity: Chiến tranh thế giới thứ nhất
#
# [Progress: 4/189 windows]
#   Processing window 4/10 of current file
#   [Request #4] Chủ đề 1 - Bài 1 - Window 4
#   [Request #4] Completed - Extracted 2 entities
#     Merged entity: Liên hợp quốc
#     Merged entity: Hiến chương Liên hợp quốc
#
# [Progress: 5/189 windows]
#   Processing window 5/10 of current file
#   [Request #5] Chủ đề 1 - Bài 1 - Window 5
#   [Request #5] Completed - Extracted 2 entities
#     Merged entity: Liên hợp quốc
#     Merged entity: Hiến chương Liên hợp quốc
#
# [Progress: 6/189 windows]
#   Processing window 6/10 of current file
#   [Request #6] Chủ đề 1 - Bài 1 - Window 6
#   [Request #6] Completed - Extracted 8 entities
#     Merged entity: Liên hợp quốc
#     Merged entity: Chiến tranh thế giới thứ hai
#     New entity: En Xan-va-đo (Quốc gia)
#     New entity: Goa-tê-ma-la (Quốc gia)
#     New entity: Mô-dăm-bích (Quốc gia)
#     New entity: Hiệp ước cấm phổ biến vũ khí hạt nhân (Văn kiện/Hiệp định)
#     New entity: Công ước cấm vũ khí hoá học (Văn kiện/Hiệp định)
#     New entity: Công ước cấm vũ khí hạt nhân (Văn kiện/Hiệp định)
#
# [Progress: 7/189 windows]
#   Processing window 7/10 of current file
#   [Request #7] Chủ đề 1 - Bài 1 - Window 7
#   [Request #7] Completed - Extracted 2 entities
#     Merged entity: Liên hợp quốc
#     New entity: Đại hội đồng Liên hợp quốc (Tổ chức)
#
# [Progress: 8/189 windows]
#   Processing window 8/10 of current file
#   [Request #8] Chủ đề 1 - Bài 1 - Window 8
#   [Request #8] Completed - Extracted 2 entities
#     New entity: Hội nghị Liên hợp quốc về Thương mại và Phát triển (Hội nghị)
#     Merged entity: Liên hợp quốc
#
# [Progress: 9/189 windows]
#   Processing window 9/10 of current file
#   [Request #9] Chủ đề 1 - Bài 1 - Window 9
#   [Request #9] Completed - Extracted 3 entities
#     Merged entity: Liên hợp quốc
#     New entity: Chương trình nghị sự 2030 vì sự phát triển bền vững (Chiến lược/Chủ trương)
#     New entity: Tuyên ngôn Nhân quyền (Văn kiện/Hiệp định)
#
# [Progress: 10/189 windows]
#   Processing window 10/10 of current file
#   [Request #10] Chủ đề 1 - Bài 1 - Window 10
#   [Request #10] Completed - Extracted 2 entities
#     Merged entity: Liên hợp quốc
#     New entity: Quỹ Giáo dục không thể chờ đợi (Tổ chức)
#
# Processing SGK/Nguồn/Chủ đề 1/Bài 2.txt...
#
# [Progress: 11/189 windows]
#   Processing window 1/10 of current file
#   [Request #11] Chủ đề 1 - Bài 2 - Window 1
#   [Request #11] Completed - Extracted 14 entities
#     Merged entity: Hội nghị I-an-ta
#     Merged entity: Chiến tranh thế giới thứ hai
#     New entity: phát xít Đức (Tổ chức)
#     New entity: quân phiệt Nhật Bản (Tổ chức)
#     Merged entity: Liên Xô
#     New entity: miền Đông nước Đức (Địa điểm)
#     New entity: Đông Béc-lin (Địa điểm)
#     New entity: các nước Đông Âu (Địa điểm)
#     Merged entity: Anh
#     New entity: Pháp (Quốc gia)
#     New entity: miền Tây nước Đức (Địa điểm)
#     New entity: Tây Béc-lin (Địa điểm)
#     New entity: các nước Tây Âu (Địa điểm)
#     New entity: Phần Lan (Quốc gia)
#
# [Progress: 12/189 windows]
#   Processing window 2/10 of current file
#   [Request #12] Chủ đề 1 - Bài 2 - Window 2
#   [Request #12] Completed - Extracted 8 entities
#     Merged entity: Liên Xô
#     New entity: Nhật Bản (Quốc gia)
#     New entity: Mông Cổ (Quốc gia)
#     New entity: chiến tranh Nga – Nhật (1904 – 1905) (Sự kiện)
#     New entity: quân đội Mỹ (Tổ chức)
#     New entity: bán đảo Triều Tiên (Địa điểm)
#     New entity: quân đội Liên Xô (Tổ chức)
#     New entity: vĩ tuyến 38 (Địa điểm)
#
# [Progress: 13/189 windows]
#   Processing window 3/10 of current file
#   [Request #13] Chủ đề 1 - Bài 2 - Window 3
#   [Request #13] Completed - Extracted 16 entities
#     New entity: Trung Hoa Dân quốc (Quốc gia)
#     New entity: Đảng Cộng sản (Tổ chức)
#     New entity: Mãn Châu (Địa điểm)
#     New entity: Đài Loan (Địa điểm)
#     New entity: quần đảo Bành Hồ (Địa điểm)
#     Merged entity: Liên Xô
#     New entity: Đông Nam Á (Địa điểm)
#     New entity: Nam Á (Địa điểm)
#     New entity: Tây Á (Địa điểm)
#     Merged entity: Hội nghị I-an-ta
#     New entity: Trật tự thế giới hai cực I-an-ta (Chiến lược/Chủ trương)
#     New entity: đảo Xa-kha-lin (Địa điểm)
#     New entity: quần đảo Cu-rin (Địa điểm)
#     New entity: thương cảng Đại Liên (Địa điểm)
#     New entity: cảng Lữ Thuận (Địa điểm)
#     New entity: đường sắt Nam Mãn Châu (Công trình)
#
# [Progress: 14/189 windows]
#   Processing window 4/10 of current file
#   [Request #14] Chủ đề 1 - Bài 2 - Window 4
#   [Request #14] Completed - Extracted 3 entities
#     New entity: Tổ chức Hiệp ước Bắc Đại Tây Dương (Tổ chức)
#     Merged entity: Liên Xô
#     New entity: Chiến tranh lạnh (Sự kiện)
#
# [Progress: 15/189 windows]
#   Processing window 5/10 of current file
#   [Request #15] Chủ đề 1 - Bài 2 - Window 5
#   [Request #15] Completed - Extracted 14 entities
#     New entity: chiến tranh xâm lược Việt Nam của thực dân Pháp (Sự kiện)
#     New entity: chiến tranh xâm lược Việt Nam của đế quốc Mỹ (Sự kiện)
#     New entity: Trung Đông (Địa điểm)
#     New entity: chiến tranh Trung Đông (Sự kiện)
#     New entity: I-xra-en (Quốc gia)
#     New entity: các nước A-rập (Tổ chức)
#     New entity: cách mạng Trung Quốc (Sự kiện)
#     New entity: Trung Quốc (Quốc gia)
#     Merged entity: Liên Xô
#     New entity: Đông Bắc Trung Quốc (Địa điểm)
#     New entity: Tây Âu (Địa điểm)
#     Merged entity: Nhật Bản
#     New entity: hệ thống tư bản chủ nghĩa (Chiến lược/Chủ trương)
#     New entity: Trật tự thế giới hai cực I-an-ta (Sự kiện)
#
# [Progress: 16/189 windows]
#   Processing window 6/10 of current file
#   [Request #16] Chủ đề 1 - Bài 2 - Window 6
#   [Request #16] Completed - Extracted 5 entities
#     New entity: I-an-ta (Hội nghị)
#     Merged entity: Liên Xô
#     New entity: Ních-xơn (Nhân Vật)
#     New entity: chuyến thăm chính thức đầu tiên của Tổng thống Mỹ Ních-xơn tới Liên Xô (Sự kiện)
#     New entity: thoả thuận về việc thủ tiêu các tên lửa tầm trung ở châu Âu (Văn kiện/Hiệp định)
#
# [Progress: 17/189 windows]
#   Processing window 7/10 of current file
#   [Request #17] Chủ đề 1 - Bài 2 - Window 7
#   [Request #17] Completed - Extracted 6 entities
#     Merged entity: Liên Xô
#     Merged entity: Chiến tranh lạnh
#     New entity: chủ nghĩa xã hội (Khái niệm)
#     New entity: Đông Âu (Khái niệm)
#     New entity: Trật tự thế giới hai cực I-an-ta (Khái niệm)
#     New entity: Tây Âu (Khái niệm)
#
# [Progress: 18/189 windows]
#   Processing window 8/10 of current file
#   [Request #18] Chủ đề 1 - Bài 2 - Window 8
#   [Request #18] Completed - Extracted 4 entities
#     Merged entity: Trật tự thế giới hai cực I-an-ta
#     Merged entity: Nhật Bản
#     Merged entity: Tây Âu
#     Merged entity: Liên Xô
#
# [Progress: 19/189 windows]
#   Processing window 9/10 of current file
#   [Request #19] Chủ đề 1 - Bài 2 - Window 9
#   [Request #19] Completed - Extracted 3 entities
#     Merged entity: I-an-ta
#     Merged entity: Liên Xô
#     Merged entity: Chiến tranh lạnh
#
# [Progress: 20/189 windows]
#   Processing window 10/10 of current file
#   [Request #20] Chủ đề 1 - Bài 2 - Window 10
#   [Request #20] Completed - Extracted 0 entities
#
# Processing SGK/Nguồn/Chủ đề 1/Bài 3.txt...
#
# [Progress: 21/189 windows]
#   Processing window 1/5 of current file
#   [Request #21] Chủ đề 1 - Bài 3 - Window 1
#   [Request #21] Completed - Extracted 4 entities
#     Merged entity: Chiến tranh lạnh
#     New entity: Việt Nam (Quốc gia)
#     New entity: Đổi mới (Chiến lược/Chủ trương)
#     Merged entity: I-an-ta
#
# [Progress: 22/189 windows]
#   Processing window 2/5 of current file
#   [Request #22] Chủ đề 1 - Bài 3 - Window 2
#   [Request #22] Completed - Extracted 0 entities
#
# [Progress: 23/189 windows]
#   Processing window 3/5 of current file
#   [Request #23] Chủ đề 1 - Bài 3 - Window 3
#   [Request #23] Completed - Extracted 6 entities
#     New entity: Đại hội XII của Đảng Cộng sản Việt Nam (Sự kiện)
#     Merged entity: Trung Quốc
#     New entity: Nga (Quốc gia)
#     New entity: Ấn Độ (Quốc gia)
#     Merged entity: Nhật Bản
#     New entity: Liên minh châu Âu (Tổ chức)
#
# [Progress: 24/189 windows]
#   Processing window 4/5 of current file
#   [Request #24] Chủ đề 1 - Bài 3 - Window 4
#   [Request #24] Completed - Extracted 3 entities
#     Merged entity: Nhật Bản
#     Merged entity: Liên minh châu Âu
#     Merged entity: Trung Quốc
#
# [Progress: 25/189 windows]
#   Processing window 5/5 of current file
#   [Request #25] Chủ đề 1 - Bài 3 - Window 5
#   [Request #25] Completed - Extracted 6 entities
#     Merged entity: Chiến tranh lạnh
#     New entity: G20 (Tổ chức)
#     New entity: ASEM (Tổ chức)
#     New entity: ASEAN (Tổ chức)
#     Merged entity: Trung Quốc
#
# Processing SGK/Nguồn/Chủ đề 2/Bài 4.txt...
#
# [Progress: 26/189 windows]
#   Processing window 1/6 of current file
#   [Request #26] Chủ đề 2 - Bài 4 - Window 1
#   [Request #26] Completed - Extracted 5 entities
#     Merged entity: ASEAN
#     Merged entity: Chiến tranh thế giới thứ hai
#     Merged entity: Chiến tranh lạnh
#     New entity: Hiệp hội Đông Nam Á (1961) (Tổ chức)
#     New entity: MAPHILINDO (Tổ chức)
#
# [Progress: 27/189 windows]
#   Processing window 2/6 of current file
#   [Request #27] Chủ đề 2 - Bài 4 - Window 2
#   [Request #27] Completed - Extracted 8 entities
#     Merged entity: ASEAN
#     New entity: Tuyên bố ASEAN (Văn kiện/Hiệp định)
#     New entity: Băng Cốc (Địa điểm)
#     New entity: In-đô-nê-xi-a (Quốc gia)
#     New entity: Ma-lai-xi-a (Quốc gia)
#     New entity: Phi-líp-pin (Quốc gia)
#     New entity: Xin-ga-po (Quốc gia)
#     New entity: Thái Lan (Quốc gia)
#
# [Progress: 28/189 windows]
#   Processing window 3/6 of current file
#   [Request #28] Chủ đề 2 - Bài 4 - Window 3
#   [Request #28] Completed - Extracted 3 entities
#     Merged entity: Liên hợp quốc
#     Merged entity: ASEAN
#     Merged entity: Hiến chương Liên hợp quốc
#
# [Progress: 29/189 windows]
#   Processing window 4/6 of current file
#   [Request #29] Chủ đề 2 - Bài 4 - Window 4
#   [Request #29] Completed - Extracted 4 entities
#     Merged entity: ASEAN
#     New entity: ASEAN 5 (Tổ chức)
#     New entity: ASEAN 10 (Tổ chức)
#     Merged entity: Việt Nam
#
# [Progress: 30/189 windows]
#   Processing window 5/6 of current file
#   [Request #30] Chủ đề 2 - Bài 4 - Window 5
#   [Request #30] Completed - Extracted 8 entities
#     New entity: ZOPFAN (Khái niệm)
#     Merged entity: ASEAN
#     New entity: Tuyên bố Ba-li I (Văn kiện/Hiệp định)
#     New entity: TAC (Văn kiện/Hiệp định)
#     New entity: AFTA (Văn kiện/Hiệp định)
#     New entity: ARF (Tổ chức)
#     Merged entity: Tuyên bố Ba-li II
#     New entity: Hiến chương ASEAN (Văn kiện/Hiệp định)
#
# [Progress: 31/189 windows]
#   Processing window 6/6 of current file
#   [Request #31] Chủ đề 2 - Bài 4 - Window 6
#   [Request #31] Completed - Extracted 5 entities
#     Merged entity: ASEAN
#     New entity: Cộng đồng ASEAN (Sự kiện)
#     New entity: Tuyên bố thành lập Cộng đồng ASEAN (Văn kiện/Hiệp định)
#     New entity: Tầm nhìn Cộng đồng ASEAN 2025 (Văn kiện/Hiệp định)
#     New entity: Tầm nhìn Cộng đồng ASEAN sau năm 2025 (Văn kiện/Hiệp định)
#
# Processing SGK/Nguồn/Chủ đề 2/Bài 5.txt...
#
# [Progress: 32/189 windows]
#   Processing window 1/8 of current file
#   [Request #32] Chủ đề 2 - Bài 5 - Window 1
#   [Request #32] Completed - Extracted 3 entities
#     Merged entity: ASEAN
#     New entity: Tầm nhìn ASEAN 2020 (Văn kiện/Hiệp định)
#
# [Progress: 33/189 windows]
#   Processing window 2/8 of current file
#   [Request #33] Chủ đề 2 - Bài 5 - Window 2
#   [Request #33] Completed - Extracted 2 entities
#     Merged entity: ASEAN
#     Merged entity: Hiến chương ASEAN
#
# [Progress: 34/189 windows]
#   Processing window 3/8 of current file
#   [Request #34] Chủ đề 2 - Bài 5 - Window 3
#   [Request #34] Completed - Extracted 5 entities
#     New entity: Cộng đồng ASEAN (Tổ chức)
#     Merged entity: ASEAN
#     New entity: Lộ trình xây dựng Cộng đồng ASEAN (Văn kiện/Hiệp định)
#     New entity: Hội nghị cấp cao ASEAN 14 (Hội nghị)
#     New entity: Tuyên bố Cu-a-la Lăm-pơ (Văn kiện/Hiệp định)
#
# [Progress: 35/189 windows]
#   Processing window 4/8 of current file
#   [Request #35] Chủ đề 2 - Bài 5 - Window 4
#   [Request #35] Completed - Extracted 5 entities
#     Merged entity: ASEAN
#     New entity: Cộng đồng Chính trị – An ninh ASEAN (APSC) (Tổ chức)
#     New entity: Cộng đồng Kinh tế ASEAN (AEC) (Tổ chức)
#     New entity: Cộng đồng Văn hoá – Xã hội ASEAN (ASCC) (Tổ chức)
#     New entity: Kế hoạch Tổng thể xây dựng Cộng đồng Chính trị – An ninh ASEAN (2009 - 2015) (Văn kiện/Hiệp định)
#
# [Progress: 36/189 windows]
#   Processing window 5/8 of current file
#   [Request #36] Chủ đề 2 - Bài 5 - Window 5
#   [Request #36] Completed - Extracted 4 entities
#     Merged entity: ASEAN
#     New entity: Cộng đồng Kinh tế ASEAN (Chiến lược/Chủ trương)
#     New entity: Cộng đồng Văn hoá – Xã hội ASEAN (Chiến lược/Chủ trương)
#     Merged entity: Việt Nam
#
# [Progress: 37/189 windows]
#   Processing window 6/8 of current file
#   [Request #37] Chủ đề 2 - Bài 5 - Window 6
#   [Request #37] Completed - Extracted 3 entities
#     Merged entity: Cộng đồng Văn hoá – Xã hội ASEAN
#     Merged entity: ASEAN
#     New entity: Hội nghị Cấp cao ASEAN lần thứ 37 (Hội nghị)
#
# [Progress: 38/189 windows]
#   Processing window 7/8 of current file
#   [Request #38] Chủ đề 2 - Bài 5 - Window 7
#   [Request #38] Completed - Extracted 1 entities
#     Merged entity: ASEAN
#
# [Progress: 39/189 windows]
#   Processing window 8/8 of current file
#   [Request #39] Chủ đề 2 - Bài 5 - Window 8
#   [Request #39] Completed - Extracted 1 entities
#     Merged entity: ASEAN
#
# Processing SGK/Nguồn/Chủ đề 3/Bài 6.txt...
#
# [Progress: 40/189 windows]
#   Processing window 1/9 of current file
#   [Request #40] Chủ đề 3 - Bài 6 - Window 1
#   [Request #40] Completed - Extracted 11 entities
#     Merged entity: Chiến tranh thế giới thứ hai
#     New entity: Hội nghị Pốt-xđam (Hội nghị)
#     New entity: quân Trung Hoa Dân quốc (Tổ chức)
#     New entity: quân Anh (Tổ chức)
#     New entity: vĩ tuyến 16 (Địa điểm)
#     New entity: Hi-rô-si-ma (Địa điểm)
#     New entity: Na-ga-xa-ki (Địa điểm)
#     New entity: Xô viết (Quốc gia)
#     New entity: đạo quân Quan Đông (Tổ chức)
#     Merged entity: Nhật Bản
#     New entity: Đồng minh (Tổ chức)
#
# [Progress: 41/189 windows]
#   Processing window 2/9 of current file
#   [Request #41] Chủ đề 3 - Bài 6 - Window 2
#   [Request #41] Completed - Extracted 14 entities
#     Merged entity: Nhật Bản
#     Merged entity: Đồng minh
#     New entity: Đông Dương (Địa điểm)
#     New entity: Trần Trọng Kim (Nhân Vật)
#     New entity: Tổng khởi nghĩa (Sự kiện)
#     New entity: cao trào kháng Nhật, cứu nước (Sự kiện)
#     New entity: Trung ương Đảng (Tổ chức)
#     New entity: Việt Minh (Tổ chức)
#     New entity: Uỷ ban Khởi nghĩa toàn quốc (Tổ chức)
#     New entity: Quân lệnh số 1 (Văn kiện/Hiệp định)
#     New entity: Hội nghị toàn quốc của Đảng (Hội nghị)
#     New entity: Tân Trào (Địa điểm)
#     New entity: Sơn Dương (Địa điểm)
#     New entity: Tuyên Quang (Địa điểm)
#
# [Progress: 42/189 windows]
#   Processing window 3/9 of current file
#   [Request #42] Chủ đề 3 - Bài 6 - Window 3
#   [Request #42] Completed - Extracted 10 entities
#     New entity: Đại hội Quốc dân Tân Trào (Hội nghị)
#     New entity: Tổng khởi nghĩa (Chiến lược/Chủ trương)
#     Merged entity: Việt Minh
#     New entity: Uỷ ban Dân tộc giải phóng Việt Nam (Tổ chức)
#     New entity: Hồ Chí Minh (Nhân Vật)
#     New entity: Cách mạng tháng Tám (Sự kiện)
#     New entity: Giải phóng quân (Tổ chức)
#     New entity: Võ Nguyên Giáp (Nhân Vật)
#     New entity: Thái Nguyên (Địa điểm)
#     New entity: Hà Nội (Địa điểm)
#
# [Progress: 43/189 windows]
#   Processing window 4/9 of current file
#   [Request #43] Chủ đề 3 - Bài 6 - Window 4
#   [Request #43] Completed - Extracted 13 entities
#     New entity: Bắc Giang (Địa điểm)
#     New entity: Hải Dương (Địa điểm)
#     New entity: Hà Tĩnh (Địa điểm)
#     New entity: Quảng Nam (Địa điểm)
#     Merged entity: Hà Nội
#     New entity: Phủ Khâm sai (Địa điểm)
#     New entity: Sở Cảnh sát Trung ương (Tổ chức)
#     New entity: Sở Bưu điện (Tổ chức)
#     New entity: Huế (Địa điểm)
#     New entity: Sài Gòn (Địa điểm)
#     New entity: Sở Mật thám (Tổ chức)
#     New entity: Sở Cảnh sát (Tổ chức)
#     New entity: Mặt trận Việt Minh (Tổ chức)
#
# [Progress: 44/189 windows]
#   Processing window 5/9 of current file
#   [Request #44] Chủ đề 3 - Bài 6 - Window 5
#   [Request #44] Completed - Extracted 9 entities
#     New entity: Đồng Nai Thượng (Địa điểm)
#     New entity: Hà Tiên (Địa điểm)
#     Merged entity: Nhật Bản
#     Merged entity: Hà Nội
#     Merged entity: Cách mạng tháng Tám
#     New entity: Chủ tịch Hồ Chí Minh (Nhân Vật)
#     New entity: Chính phủ lâm thời (Tổ chức)
#     New entity: Tuyên ngôn Độc lập (Văn kiện/Hiệp định)
#
# [Progress: 45/189 windows]
#   Processing window 6/9 of current file
#   [Request #45] Chủ đề 3 - Bài 6 - Window 6
#   [Request #45] Completed - Extracted 5 entities
#     New entity: Đảng Cộng sản Đông Dương (Tổ chức)
#     Merged entity: Chủ tịch Hồ Chí Minh
#     Merged entity: Mặt trận Việt Minh
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Việt Nam
#
# [Progress: 46/189 windows]
#   Processing window 7/9 of current file
#   [Request #46] Chủ đề 3 - Bài 6 - Window 7
#   [Request #46] Completed - Extracted 7 entities
#     Merged entity: Cách mạng tháng Tám
#     New entity: Việt Nam Dân chủ Cộng hòa (Quốc gia)
#     Merged entity: Đồng minh
#     New entity: Hồng quân Liên Xô (Tổ chức)
#     Merged entity: Nhật Bản
#     Merged entity: Pháp
#     New entity: Đảng (Tổ chức)
#
# [Progress: 47/189 windows]
#   Processing window 8/9 of current file
#   [Request #47] Chủ đề 3 - Bài 6 - Window 8
#   [Request #47] Completed - Extracted 3 entities
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Đảng Cộng sản Đông Dương
#     Merged entity: Việt Nam
#
# [Progress: 48/189 windows]
#   Processing window 9/9 of current file
#   [Request #48] Chủ đề 3 - Bài 6 - Window 9
#   [Request #48] Completed - Extracted 3 entities
#     Merged entity: Việt Nam
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Mặt trận Việt Minh
#
# Processing SGK/Nguồn/Chủ đề 3/Bài 7.txt...
#
# [Progress: 49/189 windows]
#   Processing window 1/17 of current file
#   [Request #49] Chủ đề 3 - Bài 7 - Window 1
#   [Request #49] Completed - Extracted 8 entities
#     New entity: Hệ thống xã hội chủ nghĩa (Chiến lược/Chủ trương)
#     New entity: Phong trào giải phóng dân tộc (Sự kiện)
#     New entity: Phong trào đấu tranh vì hoà bình, dân chủ (Sự kiện)
#     Merged entity: Trật tự thế giới hai cực I-an-ta
#     Merged entity: Chiến tranh lạnh
#     Merged entity: Việt Nam
#     New entity: Nhân dân (Khái niệm)
#     New entity: Chế độ mới (Chiến lược/Chủ trương)
#
# [Progress: 50/189 windows]
#   Processing window 2/17 of current file
#   [Request #50] Chủ đề 3 - Bài 7 - Window 2
#   [Request #50] Completed - Extracted 5 entities
#     New entity: Quân đội Nhật Bản (Tổ chức)
#     New entity: Chính phủ Pháp (Tổ chức)
#     Merged entity: Đông Dương
#     New entity: Kháng chiến của nhân dân Nam Bộ chống thực dân Pháp trở lại xâm lược (Sự kiện)
#     New entity: Sài Gòn - Chợ Lớn (Địa điểm)
#
# [Progress: 51/189 windows]
#   Processing window 3/17 of current file
#   [Request #51] Chủ đề 3 - Bài 7 - Window 3
#   [Request #51] Completed - Extracted 6 entities
#     Merged entity: Pháp
#     Merged entity: Sài Gòn
#     New entity: Uỷ ban hành chính Nam Bộ (Tổ chức)
#     New entity: cơ quan tự vệ thành phố Sài Gòn (Tổ chức)
#     New entity: Uỷ ban kháng chiến Nam Bộ (Tổ chức)
#     Merged entity: vĩ tuyến 16
#
# [Progress: 52/189 windows]
#   Processing window 4/17 of current file
#   [Request #52] Chủ đề 3 - Bài 7 - Window 4
#   [Request #52] Completed - Extracted 8 entities
#     New entity: Nam Bộ (Địa điểm)
#     New entity: Chính phủ Trung Hoa Dân quốc (Tổ chức)
#     New entity: Hiệp ước Hoa - Pháp (Văn kiện/Hiệp định)
#     Merged entity: Chủ tịch Hồ Chí Minh
#     New entity: Chính phủ Việt Nam Dân chủ Cộng hoà (Tổ chức)
#     New entity: Hiệp định Sơ bộ (Văn kiện/Hiệp định)
#     New entity: Lời kêu gọi toàn quốc kháng chiến (Sự kiện)
#
# [Progress: 53/189 windows]
#   Processing window 5/17 of current file
#   [Request #53] Chủ đề 3 - Bài 7 - Window 5
#   [Request #53] Completed - Extracted 2 entities
#     Merged entity: Pháp
#     Merged entity: Việt Nam
#
# [Progress: 54/189 windows]
#   Processing window 6/17 of current file
#   [Request #54] Chủ đề 3 - Bài 7 - Window 6
#   [Request #54] Completed - Extracted 4 entities
#     New entity: cuộc chiến đấu ở các đô thị phía Bắc vĩ tuyến 16 (Chiến dịch/Trận đánh)
#     New entity: Nam Định (Địa điểm)
#     New entity: Vinh (Địa điểm)
#
# [Progress: 55/189 windows]
#   Processing window 7/17 of current file
#   [Request #55] Chủ đề 3 - Bài 7 - Window 7
#   [Request #55] Completed - Extracted 6 entities
#     Merged entity: Hà Nội
#     New entity: Bắc Bộ Phủ (Địa điểm)
#     New entity: Bưu điện Bờ Hồ (Địa điểm)
#     New entity: ga Hàng Cỏ (Địa điểm)
#     New entity: phố Khâm Thiên (Địa điểm)
#     Merged entity: Pháp
#
# [Progress: 56/189 windows]
#   Processing window 8/17 of current file
#   [Request #56] Chủ đề 3 - Bài 7 - Window 8
#   [Request #56] Completed - Extracted 10 entities
#     New entity: Chợ Đồn (Địa điểm)
#     New entity: Chợ Rã (Địa điểm)
#     New entity: Đoan Hùng (Địa điểm)
#     New entity: Việt Bắc (Địa điểm)
#     New entity: Chiến dịch Biên giới thu – đông năm 1950 (Chiến dịch/Trận đánh)
#     New entity: Việt – Trung (Quốc gia)
#     New entity: Đông Khê (Địa điểm)
#     New entity: Đường số 4 (Địa điểm)
#     Merged entity: Pháp
#     Merged entity: Việt Nam
#
# [Progress: 57/189 windows]
#   Processing window 9/17 of current file
#   [Request #57] Chủ đề 3 - Bài 7 - Window 9
#   [Request #57] Completed - Extracted 5 entities
#     New entity: Kế hoạch Rơ-ve (Chiến lược/Chủ trương)
#     Merged entity: Việt Bắc
#     Merged entity: Pháp
#     New entity: Đại hội đại biểu lần thứ II của Đảng Cộng sản Đông Dương (Hội nghị)
#
# [Progress: 58/189 windows]
#   Processing window 10/17 of current file
#   [Request #58] Chủ đề 3 - Bài 7 - Window 10
#   [Request #58] Completed - Extracted 1 entities
#     Merged entity: Việt Nam
#
# [Progress: 59/189 windows]
#   Processing window 11/17 of current file
#   [Request #59] Chủ đề 3 - Bài 7 - Window 11
#   [Request #59] Completed - Extracted 3 entities
#     New entity: Mặt trận Liên Việt (Tổ chức)
#     Merged entity: Việt Minh
#     New entity: Hội Liên Việt (Tổ chức)
#
# [Progress: 60/189 windows]
#   Processing window 12/17 of current file
#   [Request #60] Chủ đề 3 - Bài 7 - Window 12
#   [Request #60] Completed - Extracted 6 entities
#     New entity: Luật Cải cách ruộng đất (Văn kiện/Hiệp định)
#     New entity: Đại hội Chiến sĩ thi đua và Cán bộ gương mẫu toàn quốc lần thứ nhất (Sự kiện)
#     Merged entity: Chủ tịch Hồ Chí Minh
#     Merged entity: Pháp
#     New entity: Kế hoạch Na-va (Chiến lược/Chủ trương)
#     Merged entity: Việt Nam
#
# [Progress: 61/189 windows]
#   Processing window 13/17 of current file
#   [Request #61] Chủ đề 3 - Bài 7 - Window 13
#   [Request #61] Completed - Extracted 11 entities
#     New entity: Đông – Xuân 1953 – 1954 (Chiến dịch/Trận đánh)
#     Merged entity: Kế hoạch Na-va
#     New entity: Điện Biên Phủ (Chiến dịch/Trận đánh)
#     New entity: Bộ Chính trị Trung ương Đảng (Tổ chức)
#     New entity: Him Lam (Địa điểm)
#     New entity: Đồi Độc Lập (Địa điểm)
#     New entity: Bản Kéo (Địa điểm)
#     New entity: Phân khu Trung tâm (Địa điểm)
#     New entity: Sân bay Mường Thanh (Địa điểm)
#     Merged entity: Pháp
#     Merged entity: Việt Nam
#
# [Progress: 62/189 windows]
#   Processing window 14/17 of current file
#   [Request #62] Chủ đề 3 - Bài 7 - Window 14
#   [Request #62] Completed - Extracted 5 entities
#     Merged entity: Điện Biên Phủ
#     New entity: Đờ Ca-xtơ-ri (Nhân Vật)
#     New entity: Hiệp định Giơ-ne-vơ (Văn kiện/Hiệp định)
#     Merged entity: Pháp
#     New entity: Miền Bắc (Địa điểm)
#
# [Progress: 63/189 windows]
#   Processing window 15/17 of current file
#   [Request #63] Chủ đề 3 - Bài 7 - Window 15
#   [Request #63] Completed - Extracted 8 entities
#     New entity: Tố Hữu (Nhân Vật)
#     Merged entity: Chủ tịch Hồ Chí Minh
#     Merged entity: Đảng
#     New entity: Liên minh nhân dân Việt – Miên – Lào (Tổ chức)
#     Merged entity: Pháp
#     Merged entity: Việt Nam
#     New entity: Lào (Quốc gia)
#     New entity: Cam-pu-chia (Quốc gia)
#
# [Progress: 64/189 windows]
#   Processing window 16/17 of current file
#   [Request #64] Chủ đề 3 - Bài 7 - Window 16
#   [Request #64] Completed - Extracted 6 entities
#     Merged entity: Trung Quốc
#     Merged entity: Liên Xô
#     New entity: nhân dân Pháp (Khái niệm)
#     New entity: nhân dân Việt Nam (Khái niệm)
#     New entity: thực dân Pháp (Tổ chức)
#     Merged entity: Việt Nam
#
# [Progress: 65/189 windows]
#   Processing window 17/17 of current file
#   [Request #65] Chủ đề 3 - Bài 7 - Window 17
#   [Request #65] Completed - Extracted 14 entities
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: miền Bắc
#     New entity: chủ nghĩa xã hội (Chiến lược/Chủ trương)
#     New entity: miền Nam (Địa điểm)
#     New entity: chủ nghĩa đế quốc (Chiến lược/Chủ trương)
#     Merged entity: Chiến tranh thế giới thứ hai
#     Merged entity: Lào
#     Merged entity: Cam-pu-chia
#     New entity: bán đảo Đông Dương (Địa điểm)
#     New entity: hệ thống thuộc địa (Chiến lược/Chủ trương)
#     New entity: châu Á (Địa điểm)
#     New entity: châu Phi (Địa điểm)
#     New entity: khu vực Mỹ La-tinh (Địa điểm)
#
# Processing SGK/Nguồn/Chủ đề 3/Bài 8.txt...
#
# [Progress: 66/189 windows]
#   Processing window 1/21 of current file
#   [Request #66] Chủ đề 3 - Bài 8 - Window 1
#   [Request #66] Completed - Extracted 12 entities
#     Merged entity: Hiệp định Giơ-ne-vơ
#     New entity: Ngô Đình Diệm (Nhân Vật)
#     New entity: chính quyền Sài Gòn (Tổ chức)
#     Merged entity: Việt Nam
#     Merged entity: miền Bắc
#     Merged entity: miền Nam
#     Merged entity: chủ nghĩa xã hội
#     Merged entity: Liên Xô
#     New entity: phe xã hội chủ nghĩa (Tổ chức)
#     Merged entity: Chiến tranh lạnh
#     New entity: phong trào giải phóng dân tộc (Chiến lược/Chủ trương)
#     Merged entity: Pháp
#
# [Progress: 67/189 windows]
#   Processing window 2/21 of current file
#   [Request #67] Chủ đề 3 - Bài 8 - Window 2
#   [Request #67] Completed - Extracted 6 entities
#     New entity: cải cách ruộng đất (Chiến lược/Chủ trương)
#     Merged entity: hiệp định Giơ-ne-vơ
#     New entity: Đồng khởi (Sự kiện)
#     Merged entity: miền Bắc
#     Merged entity: miền Nam
#     New entity: chính quyền Ngô Đình Diệm (Tổ chức)
#
# [Progress: 68/189 windows]
#   Processing window 3/21 of current file
#   [Request #68] Chủ đề 3 - Bài 8 - Window 3
#   [Request #68] Completed - Extracted 9 entities
#     New entity: Đảng Lao động Việt Nam (Tổ chức)
#     New entity: Hội nghị Ban Chấp hành Trung ương lần thứ 15 của Đảng Lao động Việt Nam (Hội nghị)
#     New entity: Vĩnh Thạnh (Địa điểm)
#     New entity: Bắc Ái (Địa điểm)
#     New entity: Trà Bồng (Địa điểm)
#     New entity: Bến Tre (Địa điểm)
#     New entity: Nguyễn Thị Định (Nhân Vật)
#     Merged entity: Ngô Đình Diệm
#
# [Progress: 69/189 windows]
#   Processing window 4/21 of current file
#   [Request #69] Chủ đề 3 - Bài 8 - Window 4
#   [Request #69] Completed - Extracted 6 entities
#     New entity: Mặt trận Dân tộc giải phóng miền Nam Việt Nam (Tổ chức)
#     New entity: Đại hội đại biểu toàn quốc lần thứ III Đảng Lao động Việt Nam (Hội nghị)
#     New entity: kế hoạch Nhà nước 5 năm lần thứ nhất (Chiến lược/Chủ trương)
#     Merged entity: miền Nam
#     Merged entity: miền Bắc
#     Merged entity: Hà Nội
#
# [Progress: 70/189 windows]
#   Processing window 5/21 of current file
#   [Request #70] Chủ đề 3 - Bài 8 - Window 5
#   [Request #70] Completed - Extracted 4 entities
#     Merged entity: miền Bắc
#     Merged entity: miền Nam
#     New entity: Chiến tranh đặc biệt (Chiến lược/Chủ trương)
#     Merged entity: chính quyền Sài Gòn
#
# [Progress: 71/189 windows]
#   Processing window 6/21 of current file
#   [Request #71] Chủ đề 3 - Bài 8 - Window 6
#   [Request #71] Completed - Extracted 5 entities
#     Merged entity: Chiến tranh đặc biệt
#     New entity: Xta-lây Tay-lo (Nhân Vật)
#     Merged entity: Ngô Đình Diệm
#     New entity: ấp chiến lược (Khái niệm)
#     New entity: Đại hội đại biểu toàn quốc lần thứ III của Đảng (Hội nghị)
#
# [Progress: 72/189 windows]
#   Processing window 7/21 of current file
#   [Request #72] Chủ đề 3 - Bài 8 - Window 7
#   [Request #72] Completed - Extracted 4 entities
#     New entity: Quân Giải phóng miền Nam (Tổ chức)
#     Merged entity: Ngô Đình Diệm
#     New entity: ấp chiến lược (Chiến lược/Chủ trương)
#     New entity: Chiến tranh đặc biệt (Khái niệm)
#
# [Progress: 73/189 windows]
#   Processing window 8/21 of current file
#   [Request #73] Chủ đề 3 - Bài 8 - Window 8
#   [Request #73] Completed - Extracted 10 entities
#     New entity: Ấp Bắc (Chiến dịch/Trận đánh)
#     New entity: Bình Giã (Chiến dịch/Trận đánh)
#     New entity: An Lão (Chiến dịch/Trận đánh)
#     New entity: Ba Gia (Chiến dịch/Trận đánh)
#     New entity: Đồng Xoài (Chiến dịch/Trận đánh)
#     Merged entity: Chiến tranh đặc biệt
#     New entity: Chiến tranh cục bộ (Chiến lược/Chủ trương)
#     Merged entity: miền Nam
#     Merged entity: miền Bắc
#     New entity: quân đội Sài Gòn (Tổ chức)
#
# [Progress: 74/189 windows]
#   Processing window 9/21 of current file
#   [Request #74] Chủ đề 3 - Bài 8 - Window 9
#   [Request #74] Completed - Extracted 6 entities
#     Merged entity: Chiến tranh cục bộ
#     Merged entity: ấp chiến lược
#     New entity: Mặt trận Dân tộc Giải phóng miền Nam (Tổ chức)
#     New entity: Quân Giải phóng (Tổ chức)
#     New entity: Vạn Tường (Địa điểm)
#     New entity: Quảng Ngãi (Địa điểm)
#
# [Progress: 75/189 windows]
#   Processing window 10/21 of current file
#   [Request #75] Chủ đề 3 - Bài 8 - Window 10
#   [Request #75] Completed - Extracted 8 entities
#     Merged entity: Vạn Tường
#     Merged entity: Chiến tranh cục bộ
#     New entity: Xuân Mậu Thân (Sự kiện)
#     New entity: Tổng tiến công và nổi dậy (1968) (Sự kiện)
#     New entity: phi Mỹ hoả (Chiến lược/Chủ trương)
#     Merged entity: miền Bắc
#     New entity: Vịnh Bắc Bộ (Sự kiện)
#     New entity: Pa-ri (Địa điểm)
#
# [Progress: 76/189 windows]
#   Processing window 11/21 of current file
#   [Request #76] Chủ đề 3 - Bài 8 - Window 11
#   [Request #76] Completed - Extracted 2 entities
#     Merged entity: Việt Nam
#     Merged entity: Chiến tranh cục bộ
#
# [Progress: 77/189 windows]
#   Processing window 12/21 of current file
#   [Request #77] Chủ đề 3 - Bài 8 - Window 12
#   [Request #77] Completed - Extracted 2 entities
#     New entity: Việt Nam hoá chiến tranh (Chiến lược/Chủ trương)
#     Merged entity: Đông Dương
#
# [Progress: 78/189 windows]
#   Processing window 13/21 of current file
#   [Request #78] Chủ đề 3 - Bài 8 - Window 13
#   [Request #78] Completed - Extracted 10 entities
#     Merged entity: Việt Nam
#     Merged entity: Lào
#     Merged entity: Cam-pu-chia
#     Merged entity: Sài Gòn
#     New entity: Hội nghị cấp cao ba nước Việt Nam – Lào – Cam-pu-chia (Hội nghị)
#     New entity: cuộc hành quân xâm lược (Sự kiện)
#     New entity: Tiến công chiến lược vào Quảng Trị (Chiến dịch/Trận đánh)
#     New entity: Quảng Trị (Địa điểm)
#     New entity: Tây Nguyên (Địa điểm)
#     New entity: Đông Nam Bộ (Địa điểm)
#
# [Progress: 79/189 windows]
#   Processing window 14/21 of current file
#   [Request #79] Chủ đề 3 - Bài 8 - Window 14
#   [Request #79] Completed - Extracted 7 entities
#     New entity: Cuộc Tiến công chiến lược năm 1972 (Chiến dịch/Trận đánh)
#     New entity: đường Hồ Chí Minh (Công trình)
#     Merged entity: Lào
#     Merged entity: Cam-pu-chia
#     Merged entity: Hà Nội
#     New entity: Hải Phòng (Địa điểm)
#     New entity: B52 (Khái niệm)
#
# [Progress: 80/189 windows]
#   Processing window 15/21 of current file
#   [Request #80] Chủ đề 3 - Bài 8 - Window 15
#   [Request #80] Completed - Extracted 7 entities
#     New entity: Điện Biên Phủ trên không (Chiến dịch/Trận đánh)
#     New entity: Hiệp định Pa-ri (Văn kiện/Hiệp định)
#     Merged entity: Việt Nam
#     Merged entity: miền Bắc
#     Merged entity: miền Nam
#     Merged entity: Lào
#     Merged entity: Cam-pu-chia
#
# [Progress: 81/189 windows]
#   Processing window 16/21 of current file
#   [Request #81] Chủ đề 3 - Bài 8 - Window 16
#   [Request #81] Completed - Extracted 4 entities
#     Merged entity: Hiệp định Pa-ri
#     New entity: chiến dịch Đường 14 – Phước Long (Chiến dịch/Trận đánh)
#     Merged entity: chính quyền Sài Gòn
#
# [Progress: 82/189 windows]
#   Processing window 17/21 of current file
#   [Request #82] Chủ đề 3 - Bài 8 - Window 17
#   [Request #82] Completed - Extracted 7 entities
#     New entity: Tổng tiến công và nổi dậy Xuân 1975 (Sự kiện)
#     New entity: Chiến dịch Tây Nguyên (Chiến dịch/Trận đánh)
#     New entity: Chiến dịch giải phóng Sài Gòn – Gia Định (Chiến dịch/Trận đánh)
#     Merged entity: Huế
#     New entity: Thừa Thiên (Địa điểm)
#     New entity: Đà Nẵng (Địa điểm)
#     New entity: Sài Gòn – Gia Định (Địa điểm)
#
# [Progress: 83/189 windows]
#   Processing window 18/21 of current file
#   [Request #83] Chủ đề 3 - Bài 8 - Window 18
#   [Request #83] Completed - Extracted 10 entities
#     Merged entity: Võ Nguyên Giáp
#     New entity: Quân ủy Trung ương (Tổ chức)
#     New entity: Bộ Tổng Tư lệnh (Tổ chức)
#     New entity: Xuân Lộc (Địa điểm)
#     New entity: Phan Rang (Địa điểm)
#     New entity: Dinh Độc Lập (Địa điểm)
#     New entity: cuộc kháng chiến chống Mỹ, cứu nước (Sự kiện)
#     Merged entity: Hồ Chí Minh
#
# [Progress: 84/189 windows]
#   Processing window 19/21 of current file
#   [Request #84] Chủ đề 3 - Bài 8 - Window 19
#   [Request #84] Completed - Extracted 6 entities
#     New entity: cách mạng xã hội chủ nghĩa ở miền Bắc (Chiến lược/Chủ trương)
#     New entity: cách mạng dân tộc dân chủ nhân dân ở miền Nam (Chiến lược/Chủ trương)
#     New entity: chiến tranh nhân dân (Chiến lược/Chủ trương)
#     New entity: Nhân dân Việt Nam (Tổ chức)
#     Merged entity: Liên Xô
#     Merged entity: Việt Nam
#
# [Progress: 85/189 windows]
#   Processing window 20/21 of current file
#   [Request #85] Chủ đề 3 - Bài 8 - Window 20
#   [Request #85] Completed - Extracted 6 entities
#     Merged entity: Việt Nam
#     New entity: Đông Dương (Khái niệm)
#     Merged entity: chủ nghĩa xã hội
#     Merged entity: cuộc kháng chiến chống Mỹ, cứu nước
#     New entity: chủ nghĩa anh hùng cách mạng (Khái niệm)
#     New entity: cách mạng dân tộc dân chủ nhân dân (Sự kiện)
#
# [Progress: 86/189 windows]
#   Processing window 21/21 of current file
#   [Request #86] Chủ đề 3 - Bài 8 - Window 21
#   [Request #86] Completed - Extracted 3 entities
#     Merged entity: Việt Nam
#     New entity: chủ nghĩa thực dân mới (Chiến lược/Chủ trương)
#     Merged entity: chủ nghĩa xã hội
#
# Processing SGK/Nguồn/Chủ đề 3/Bài 9.txt...
#
# [Progress: 87/189 windows]
#   Processing window 1/14 of current file
#   [Request #87] Chủ đề 3 - Bài 9 - Window 1
#   [Request #87] Completed - Extracted 4 entities
#     Merged entity: Việt Nam
#     Merged entity: chủ nghĩa xã hội
#     Merged entity: Trung Quốc
#     Merged entity: Cam-pu-chia
#
# [Progress: 88/189 windows]
#   Processing window 2/14 of current file
#   [Request #88] Chủ đề 3 - Bài 9 - Window 2
#   [Request #88] Completed - Extracted 4 entities
#     New entity: Pôn Pốt (Tổ chức)
#     New entity: Phú Quốc (Địa điểm)
#     New entity: Thổ Chu (Địa điểm)
#     New entity: An Giang (Địa điểm)
#
# [Progress: 89/189 windows]
#   Processing window 3/14 of current file
#   [Request #89] Chủ đề 3 - Bài 9 - Window 3
#   [Request #89] Completed - Extracted 5 entities
#     New entity: Quân Pôn Pốt (Tổ chức)
#     New entity: Tây Ninh (Địa điểm)
#     New entity: Mặt trận Đoàn kết dân tộc cứu nước Cam-pu-chia (Tổ chức)
#     New entity: quân tình nguyện Việt Nam (Tổ chức)
#     New entity: Phôm Pênh (Địa điểm)
#
# [Progress: 90/189 windows]
#   Processing window 4/14 of current file
#   [Request #90] Chủ đề 3 - Bài 9 - Window 4
#   [Request #90] Completed - Extracted 4 entities
#     New entity: Nhà mồ Ba Chúc (Địa điểm)
#     Merged entity: quân Pôn Pốt
#     Merged entity: Việt Nam
#     Merged entity: Trung Quốc
#
# [Progress: 91/189 windows]
#   Processing window 5/14 of current file
#   [Request #91] Chủ đề 3 - Bài 9 - Window 5
#   [Request #91] Completed - Extracted 7 entities
#     Merged entity: Việt Nam
#     Merged entity: Trung Quốc
#     New entity: Lạng Sơn (Địa điểm)
#     New entity: Cao Bằng (Địa điểm)
#     New entity: Lào Cai (Địa điểm)
#     New entity: Vị Xuyên (Địa điểm)
#     New entity: Hà Giang (Địa điểm)
#
# [Progress: 92/189 windows]
#   Processing window 6/14 of current file
#   [Request #92] Chủ đề 3 - Bài 9 - Window 6
#   [Request #92] Completed - Extracted 4 entities
#     Merged entity: Vị Xuyên
#     New entity: Tuyên bố về lãnh hải, vùng tiếp giáp, vùng đặc quyền kinh tế và thềm lục địa của Việt Nam (Văn kiện/Hiệp định)
#     New entity: Công ước của Liên hợp quốc về Luật Biển (UNCLOS) năm 1982 (Văn kiện/Hiệp định)
#     Merged entity: Liên hợp quốc
#
# [Progress: 93/189 windows]
#   Processing window 7/14 of current file
#   [Request #93] Chủ đề 3 - Bài 9 - Window 7
#   [Request #93] Completed - Extracted 9 entities
#     New entity: Hoàng Sa (Địa điểm)
#     New entity: Trường Sa (Địa điểm)
#     Merged entity: Trường Sa
#     Merged entity: Việt Nam
#     Merged entity: Trung Quốc
#     New entity: Gạc Ma (Địa điểm)
#     New entity: Cô Lin (Địa điểm)
#     New entity: Len Đao (Địa điểm)
#     New entity: Tháng 3 – 1988 (Sự kiện)
#
# [Progress: 94/189 windows]
#   Processing window 8/14 of current file
#   [Request #94] Chủ đề 3 - Bài 9 - Window 8
#   [Request #94] Completed - Extracted 6 entities
#     New entity: Hải quân Việt Nam (Tổ chức)
#     Merged entity: Liên hợp quốc
#     Merged entity: Việt Nam
#     Merged entity: Trung Quốc
#     New entity: Luật biển Việt Nam (Văn kiện/Hiệp định)
#     New entity: Tuyên bố ứng xử của các bên ở Biển Đông (DOC) (Văn kiện/Hiệp định)
#
# [Progress: 95/189 windows]
#   Processing window 9/14 of current file
#   [Request #95] Chủ đề 3 - Bài 9 - Window 9
#   [Request #95] Completed - Extracted 2 entities
#     Merged entity: Việt Nam
#     New entity: tháng 4 – 1975 (Sự kiện)
#
# [Progress: 96/189 windows]
#   Processing window 10/14 of current file
#   [Request #96] Chủ đề 3 - Bài 9 - Window 10
#   [Request #96] Completed - Extracted 2 entities
#     Merged entity: Việt Nam
#     New entity: 1945 (Khái niệm)
#
# [Progress: 97/189 windows]
#   Processing window 11/14 of current file
#   [Request #97] Chủ đề 3 - Bài 9 - Window 11
#   [Request #97] Completed - Extracted 2 entities
#     New entity: Đảng Cộng sản Việt Nam (Tổ chức)
#     Merged entity: Việt Nam
#
# [Progress: 98/189 windows]
#   Processing window 12/14 of current file
#   [Request #98] Chủ đề 3 - Bài 9 - Window 12
#   [Request #98] Completed - Extracted 2 entities
#     Merged entity: Việt Nam
#     New entity: Mặt trận Tổ quốc Việt Nam (Tổ chức)
#
# [Progress: 99/189 windows]
#   Processing window 13/14 of current file
#   [Request #99] Chủ đề 3 - Bài 9 - Window 13
#   [Request #99] Completed - Extracted 3 entities
#     Merged entity: Đảng Cộng sản Việt Nam
#     Merged entity: Chủ tịch Hồ Chí Minh
#     Merged entity: Việt Nam
#
# [Progress: 100/189 windows]
#   Processing window 14/14 of current file
#   [Request #100] Chủ đề 3 - Bài 9 - Window 14
#   [Request #100] Completed - Extracted 1 entities
#     Merged entity: Việt Nam
#
# Processing SGK/Nguồn/Chủ đề 4/Bài 10.txt...
#
# [Progress: 101/189 windows]
#   Processing window 1/8 of current file
#   [Request #101] Chủ đề 4 - Bài 10 - Window 1
#   [Request #101] Completed - Extracted 4 entities
#     New entity: Công cuộc Đổi mới (Chiến lược/Chủ trương)
#     New entity: Đại hội đại biểu toàn quốc lần thứ VI (Hội nghị)
#     Merged entity: Đại hội đại biểu toàn quốc lần thứ VII
#     Merged entity: Việt Nam
#
# [Progress: 102/189 windows]
#   Processing window 2/8 of current file
#   [Request #102] Chủ đề 4 - Bài 10 - Window 2
#   [Request #102] Completed - Extracted 5 entities
#     Merged entity: Việt Nam
#     New entity: Ba chương trình kinh tế lớn (Chiến lược/Chủ trương)
#     New entity: Đổi mới toàn diện và đồng bộ (Chiến lược/Chủ trương)
#     New entity: Đổi mới kinh tế (Chiến lược/Chủ trương)
#     New entity: đổi mới chính trị (Chiến lược/Chủ trương)
#
# [Progress: 103/189 windows]
#   Processing window 3/8 of current file
#   [Request #103] Chủ đề 4 - Bài 10 - Window 3
#   [Request #103] Completed - Extracted 2 entities
#     Merged entity: Đổi mới
#     Merged entity: Việt Nam
#
# [Progress: 104/189 windows]
#   Processing window 4/8 of current file
#   [Request #104] Chủ đề 4 - Bài 10 - Window 4
#   [Request #104] Completed - Extracted 4 entities
#     Merged entity: Đảng Cộng sản Việt Nam
#     Merged entity: Việt Nam
#     New entity: kinh tế thị trường định hướng xã hội chủ nghĩa (Chiến lược/Chủ trương)
#
# [Progress: 105/189 windows]
#   Processing window 5/8 of current file
#   [Request #105] Chủ đề 4 - Bài 10 - Window 5
#   [Request #105] Completed - Extracted 0 entities
#
# [Progress: 106/189 windows]
#   Processing window 6/8 of current file
#   [Request #106] Chủ đề 4 - Bài 10 - Window 6
#   [Request #106] Completed - Extracted 4 entities
#     Merged entity: Đổi mới
#     Merged entity: Đảng Cộng sản Việt Nam
#     New entity: Đại hội đại biểu toàn quốc lần thứ X của Đảng Cộng sản Việt Nam (Hội nghị)
#     Merged entity: Việt Nam
#
# [Progress: 107/189 windows]
#   Processing window 7/8 of current file
#   [Request #107] Chủ đề 4 - Bài 10 - Window 7
#   [Request #107] Completed - Extracted 5 entities
#     Merged entity: Việt Nam
#     New entity: hội nhập quốc tế sâu rộng (Chiến lược/Chủ trương)
#     Merged entity: đổi mới
#     Merged entity: kinh tế thị trường định hướng xã hội chủ nghĩa
#     New entity: kinh tế tri thức (Khái niệm)
#
# [Progress: 108/189 windows]
#   Processing window 8/8 of current file
#   [Request #108] Chủ đề 4 - Bài 10 - Window 8
#   [Request #108] Completed - Extracted 1 entities
#     Merged entity: Việt Nam
#
# Processing SGK/Nguồn/Chủ đề 4/Bài 11.txt...
#
# [Progress: 109/189 windows]
#   Processing window 1/15 of current file
#   [Request #109] Chủ đề 4 - Bài 11 - Window 1
#   [Request #109] Completed - Extracted 3 entities
#     Merged entity: Công cuộc Đổi mới
#     Merged entity: Việt Nam
#     New entity: kinh tế thị trường xã hội chủ nghĩa (Chiến lược/Chủ trương)
#
# [Progress: 110/189 windows]
#   Processing window 2/15 of current file
#   [Request #110] Chủ đề 4 - Bài 11 - Window 2
#   [Request #110] Completed - Extracted 3 entities
#     Merged entity: Đổi mới
#     Merged entity: Việt Nam
#     New entity: COVID-19 (Sự kiện)
#
# [Progress: 111/189 windows]
#   Processing window 3/15 of current file
#   [Request #111] Chủ đề 4 - Bài 11 - Window 3
#   [Request #111] Completed - Extracted 0 entities
#
# [Progress: 112/189 windows]
#   Processing window 4/15 of current file
#   [Request #112] Chủ đề 4 - Bài 11 - Window 4
#   [Request #112] Completed - Extracted 1 entities
#     Merged entity: Việt Nam
#
# [Progress: 113/189 windows]
#   Processing window 5/15 of current file
#   [Request #113] Chủ đề 4 - Bài 11 - Window 5
#   [Request #113] Completed - Extracted 5 entities
#     Merged entity: Việt Nam
#     New entity: Nhà nước pháp quyền xã hội chủ nghĩa (Chiến lược/Chủ trương)
#     Merged entity: Đổi mới
#     New entity: Mục tiêu Thiên niên kỉ (MDGs) (Hội nghị)
#     Merged entity: Liên hợp quốc
#
# [Progress: 114/189 windows]
#   Processing window 6/15 of current file
#   [Request #114] Chủ đề 4 - Bài 11 - Window 6
#   [Request #114] Completed - Extracted 0 entities
#
# [Progress: 115/189 windows]
#   Processing window 7/15 of current file
#   [Request #115] Chủ đề 4 - Bài 11 - Window 7
#   [Request #115] Completed - Extracted 0 entities
#
# [Progress: 116/189 windows]
#   Processing window 8/15 of current file
#   [Request #116] Chủ đề 4 - Bài 11 - Window 8
#   [Request #116] Completed - Extracted 2 entities
#     Merged entity: Việt Nam
#     Merged entity: Đổi mới
#
# [Progress: 117/189 windows]
#   Processing window 9/15 of current file
#   [Request #117] Chủ đề 4 - Bài 11 - Window 9
#   [Request #117] Completed - Extracted 1 entities
#     Merged entity: Việt Nam
#
# [Progress: 118/189 windows]
#   Processing window 10/15 of current file
#   [Request #118] Chủ đề 4 - Bài 11 - Window 10
#   [Request #118] Completed - Extracted 2 entities
#     Merged entity: Việt Nam
#     Merged entity: Liên hợp quốc
#
# [Progress: 119/189 windows]
#   Processing window 11/15 of current file
#   [Request #119] Chủ đề 4 - Bài 11 - Window 11
#   [Request #119] Completed - Extracted 1 entities
#     Merged entity: Việt Nam
#
# [Progress: 120/189 windows]
#   Processing window 12/15 of current file
#   [Request #120] Chủ đề 4 - Bài 11 - Window 12
#   [Request #120] Completed - Extracted 1 entities
#     Merged entity: Việt Nam
#
# [Progress: 121/189 windows]
#   Processing window 13/15 of current file
#   [Request #121] Chủ đề 4 - Bài 11 - Window 13
#   [Request #121] Completed - Extracted 6 entities
#     Merged entity: Đổi mới
#     Merged entity: Chủ nghĩa xã hội
#     New entity: chủ nghĩa Mác – Lê-nin (Khái niệm)
#     New entity: tư tưởng Hồ Chí Minh (Khái niệm)
#     Merged entity: Việt Nam
#     Merged entity: Hồ Chí Minh
#
# [Progress: 122/189 windows]
#   Processing window 14/15 of current file
#   [Request #122] Chủ đề 4 - Bài 11 - Window 14
#   [Request #122] Completed - Extracted 2 entities
#     Merged entity: Việt Nam
#     Merged entity: Đổi mới
#
# [Progress: 123/189 windows]
#   Processing window 15/15 of current file
#   [Request #123] Chủ đề 4 - Bài 11 - Window 15
#   [Request #123] Completed - Extracted 0 entities
#
# Processing SGK/Nguồn/Chủ đề 5/Bài 12.txt...
#
# [Progress: 124/189 windows]
#   Processing window 1/8 of current file
#   [Request #124] Chủ đề 5 - Bài 12 - Window 1
#   [Request #124] Completed - Extracted 7 entities
#     New entity: Phan Bội Châu (Nhân Vật)
#     Merged entity: Nhật Bản
#     Merged entity: Trung Quốc
#     Merged entity: Pháp
#     New entity: Điền - Quế - Việt liên minh (Tổ chức)
#     New entity: Đông Á đồng minh (Tổ chức)
#     New entity: Phan Châu Trinh (Nhân Vật)
#
# [Progress: 125/189 windows]
#   Processing window 2/8 of current file
#   [Request #125] Chủ đề 5 - Bài 12 - Window 2
#   [Request #125] Completed - Extracted 9 entities
#     Merged entity: Phan Bội Châu
#     Merged entity: Trung Quốc
#     New entity: Việt Nam Quang phục hội (Tổ chức)
#     New entity: Chấn Hoa Hưng Á (Tổ chức)
#     New entity: Công sứ Đức (Nhân Vật)
#     New entity: Đại sứ quán Nga (Tổ chức)
#     Merged entity: Phan Châu Trinh
#     Merged entity: Pháp
#
# [Progress: 126/189 windows]
#   Processing window 3/8 of current file
#   [Request #126] Chủ đề 5 - Bài 12 - Window 3
#   [Request #126] Completed - Extracted 5 entities
#     Merged entity: Phan Châu Trinh
#     Merged entity: Pháp
#     Merged entity: Chính phủ Pháp
#     New entity: Nguyễn Ái Quốc (Nhân Vật)
#     Merged entity: Đảng Cộng sản Đông Dương
#
# [Progress: 127/189 windows]
#   Processing window 4/8 of current file
#   [Request #127] Chủ đề 5 - Bài 12 - Window 4
#   [Request #127] Completed - Extracted 7 entities
#     Merged entity: Nguyễn Ái Quốc
#     New entity: Đảng Cộng sản Pháp (Tổ chức)
#     New entity: Hội Liên hiệp thuộc địa (Tổ chức)
#     Merged entity: Đông Dương
#     Merged entity: Liên Xô
#     Merged entity: Trung Quốc
#     New entity: Quốc tế Cộng sản (Tổ chức)
#
# [Progress: 128/189 windows]
#   Processing window 5/8 of current file
#   [Request #128] Chủ đề 5 - Bài 12 - Window 5
#   [Request #128] Completed - Extracted 10 entities
#     Merged entity: Nguyễn Ái Quốc
#     Merged entity: Quốc tế Cộng sản
#     Merged entity: Trung Quốc
#     New entity: Đông Nam Á (Khái niệm)
#     New entity: Hội Liên hiệp các dân tộc bị áp bức ở Á Đông (Tổ chức)
#     Merged entity: Việt Nam
#     Merged entity: Ấn Độ
#     New entity: Triều Tiên (Quốc gia)
#     Merged entity: In-đô-nê-xi-a
#     New entity: Miến Điện (Quốc gia)
#
# ...
#     Merged entity: Đảng Cộng sản Pháp
#     Merged entity: Pháp
#     Merged entity: Việt Nam
#
# [Progress: 156/189 windows]
#   Processing window 10/13 of current file
#   [Request #156] Chủ đề 6 - Bài 15 - Window 10
#   [Request #156] Completed - Extracted 15 entities
#     New entity: Hội Liên hiệp các dân tộc thuộc địa (Tổ chức)
#     New entity: Người cùng khổ (Văn kiện/Hiệp định)
#     Merged entity: Liên Xô
#     New entity: Quảng Châu (Địa điểm)
#     New entity: Hội Việt Nam cách mạng Thanh niên (Tổ chức)
#     New entity: Thanh niên (Văn kiện/Hiệp định)
#     Merged entity: Pháp
#     New entity: Đức (Quốc gia)
#     New entity: Xiêm (Quốc gia)
#     New entity: Hương Cảng (Địa điểm)
#     Merged entity: Đảng Cộng sản Việt Nam
#     Merged entity: Trung Quốc
#     Merged entity: Việt Nam
#     New entity: Hội nghị lần thứ 8 Ban Chấp hành Trung ương Đảng Cộng sản Đông Dương (Hội nghị)
#     Merged entity: Đảng Cộng sản Đông Dương
#
# [Progress: 157/189 windows]
#   Processing window 11/13 of current file
#   [Request #157] Chủ đề 6 - Bài 15 - Window 11
#   [Request #157] Completed - Extracted 10 entities
#     Merged entity: Nguyễn Ái Quốc
#     Merged entity: Hồ Chí Minh
#     Merged entity: Trung Quốc
#     Merged entity: Trung ương Đảng
#     Merged entity: Mặt trận Việt Minh
#     New entity: Chính phủ lâm thời nước Việt Nam Dân chủ Cộng hoà (Tổ chức)
#     Merged entity: Việt Nam Dân chủ Cộng hoà
#     New entity: Quảng trường Ba Đình (Địa điểm)
#     Merged entity: Tuyên ngôn Độc lập
#
# [Progress: 158/189 windows]
#   Processing window 12/13 of current file
#   [Request #158] Chủ đề 6 - Bài 15 - Window 12
#   [Request #158] Completed - Extracted 9 entities
#     Merged entity: Chủ tịch Hồ Chí Minh
#     Merged entity: Trung ương Đảng
#     Merged entity: Đảng Cộng sản Đông Dương
#     Merged entity: Đảng Lao động Việt Nam
#     Merged entity: Việt Nam Dân chủ Cộng hoà
#     New entity: Quốc hội khoá I (Tổ chức)
#     New entity: Đại hội lần thứ II của Đảng Cộng sản Đông Dương (Sự kiện)
#     New entity: kháng chiến chống thực dân Pháp (Chiến dịch/Trận đánh)
#     New entity: kháng chiến chống Mỹ, cứu nước (Chiến dịch/Trận đánh)
#
# [Progress: 159/189 windows]
#   Processing window 13/13 of current file
#   [Request #159] Chủ đề 6 - Bài 15 - Window 13
#   [Request #159] Completed - Extracted 4 entities
#     New entity: Đại hội lần thứ III của Đảng (Hội nghị)
#     Merged entity: Hồ Chí Minh
#     Merged entity: Đảng Lao động Việt Nam
#     Merged entity: Hà Nội
#
# Processing SGK/Nguồn/Chủ đề 6/Bài 16.txt...
#
# [Progress: 160/189 windows]
#   Processing window 1/21 of current file
#   [Request #160] Chủ đề 6 - Bài 16 - Window 1
#   [Request #160] Completed - Extracted 3 entities
#     Merged entity: Nguyễn Tất Thành
#     New entity: chủ nghĩa thực dân (Khái niệm)
#     Merged entity: chủ nghĩa Mác – Lê-nin
#
# [Progress: 161/189 windows]
#   Processing window 2/21 of current file
#   [Request #161] Chủ đề 6 - Bài 16 - Window 2
#   [Request #161] Completed - Extracted 9 entities
#     Merged entity: Nguyễn Ái Quốc
#     New entity: Lê-nin (Nhân Vật)
#     New entity: báo Nhân đạo (Tổ chức)
#     New entity: Đảng Xã hội Pháp (Tổ chức)
#     Merged entity: Quốc tế Cộng sản
#     Merged entity: Đảng Cộng sản Pháp
#     Merged entity: Việt Nam
#     Merged entity: Pháp
#
# [Progress: 162/189 windows]
#   Processing window 3/21 of current file
#   [Request #162] Chủ đề 6 - Bài 16 - Window 3
#   [Request #162] Completed - Extracted 8 entities
#     Merged entity: Lê-nin
#     New entity: Mác – Lê-nin (Chiến lược/Chủ trương)
#     Merged entity: Nguyễn Ái Quốc
#     New entity: cách mạng Việt Nam (Sự kiện)
#     New entity: phong trào giải phóng dân tộc Việt Nam (Sự kiện)
#     New entity: cách mạng thế giới (Sự kiện)
#     Merged entity: Đảng Cộng sản Việt Nam
#
# [Progress: 163/189 windows]
#   Processing window 4/21 of current file
#   [Request #163] Chủ đề 6 - Bài 16 - Window 4
#   [Request #163] Completed - Extracted 5 entities
#     Merged entity: Đảng Cộng sản
#     New entity: Chủ nghĩa Lê-nin (Chiến lược/Chủ trương)
#     Merged entity: Nguyễn Ái Quốc
#     Merged entity: Hội liên hiệp thuộc địa
#     New entity: Le Paria (Tổ chức)
#
# [Progress: 164/189 windows]
#   Processing window 5/21 of current file
#   [Request #164] Chủ đề 6 - Bài 16 - Window 5
#   [Request #164] Completed - Extracted 5 entities
#     Merged entity: Nguyễn Ái Quốc
#     Merged entity: Hội Việt Nam Cách mạng Thanh niên
#     Merged entity: Quảng Châu
#     New entity: chính đảng vô sản (Tổ chức)
#
# [Progress: 165/189 windows]
#   Processing window 6/21 of current file
#   [Request #165] Chủ đề 6 - Bài 16 - Window 6
#   [Request #165] Completed - Extracted 3 entities
#     Merged entity: Đảng Cộng sản Việt Nam
#     Merged entity: Nguyễn Ái Quốc
#     Merged entity: Xiêm
#
# [Progress: 166/189 windows]
#   Processing window 7/21 of current file
#   [Request #166] Chủ đề 6 - Bài 16 - Window 7
#   [Request #166] Completed - Extracted 6 entities
#     Merged entity: Nguyễn Ái Quốc
#     Merged entity: Quốc tế Cộng sản
#     New entity: Cửu Long (Địa điểm)
#     Merged entity: Đảng Cộng sản Việt Nam
#     New entity: Chính cương vắn tắt (Văn kiện/Hiệp định)
#     New entity: Sách lược vắn tắt (Văn kiện/Hiệp định)
#
# [Progress: 167/189 windows]
#   Processing window 8/21 of current file
#   [Request #167] Chủ đề 6 - Bài 16 - Window 8
#   [Request #167] Completed - Extracted 3 entities
#     New entity: Cương lĩnh chính trị đầu tiên của Đảng Cộng sản Việt Nam (Văn kiện/Hiệp định)
#     Merged entity: Đảng Cộng sản Việt Nam
#     Merged entity: Nguyễn Ái Quốc
#
# [Progress: 168/189 windows]
#   Processing window 9/21 of current file
#   [Request #168] Chủ đề 6 - Bài 16 - Window 9
#   [Request #168] Completed - Extracted 3 entities
#     Merged entity: Đảng Cộng sản Việt Nam
#     Merged entity: Việt Nam
#     New entity: cách mạng vô sản thế giới (Chiến lược/Chủ trương)
#
# [Progress: 169/189 windows]
#   Processing window 10/21 of current file
#   [Request #169] Chủ đề 6 - Bài 16 - Window 10
#   [Request #169] Completed - Extracted 9 entities
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Hội nghị lần thứ 8 Ban Chấp hành Trung ương Đảng Cộng sản Đông Dương
#     Merged entity: Đảng Cộng sản Đông Dương
#     Merged entity: Nguyễn Ái Quốc
#     New entity: Pác Bó (Địa điểm)
#     Merged entity: Việt Nam
#     Merged entity: Lào
#     Merged entity: Cam-pu-chia
#
# [Progress: 170/189 windows]
#   Processing window 11/21 of current file
#   [Request #170] Chủ đề 6 - Bài 16 - Window 11
#   [Request #170] Completed - Extracted 6 entities
#     Merged entity: Nguyễn Ái Quốc
#     Merged entity: Pháp
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Mặt trận Việt Minh
#     Merged entity: Hồ Chí Minh
#
# [Progress: 171/189 windows]
#   Processing window 12/21 of current file
#   [Request #171] Chủ đề 6 - Bài 16 - Window 12
#   [Request #171] Completed - Extracted 6 entities
#     New entity: Chương trình cứu nước của Việt Minh (Văn kiện/Hiệp định)
#     Merged entity: Việt Minh
#     Merged entity: Pháp
#     New entity: Tiểu đội du kích thoát li đầu tiên ở Cao Bằng (Sự kiện)
#     Merged entity: Cao Bằng
#
# [Progress: 172/189 windows]
#   Processing window 13/21 of current file
#   [Request #172] Chủ đề 6 - Bài 16 - Window 13
#   [Request #172] Completed - Extracted 7 entities
#     New entity: Đội Việt Nam Tuyên truyền Giải phóng quân (Tổ chức)
#     Merged entity: Cao Bằng
#     Merged entity: Pác Bó
#     Merged entity: Tân Trào
#     New entity: Khu Giải phóng Việt Bắc (Tổ chức)
#     Merged entity: Hồ Chí Minh
#     Merged entity: Trung Quốc
#
# [Progress: 173/189 windows]
#   Processing window 14/21 of current file
#   [Request #173] Chủ đề 6 - Bài 16 - Window 14
#   [Request #173] Completed - Extracted 7 entities
#     Merged entity: Hồ Chí Minh
#     Merged entity: Trung ương Đảng
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Việt Nam Dân chủ Cộng hoà
#     Merged entity: Hội nghị toàn quốc của Đảng
#     New entity: Quốc dân đại hội đại biểu (Hội nghị)
#     New entity: Trường Sơn (Địa điểm)
#
# [Progress: 174/189 windows]
#   Processing window 15/21 of current file
#   [Request #174] Chủ đề 6 - Bài 16 - Window 15
#   [Request #174] Completed - Extracted 10 entities
#     Merged entity: Đảng Cộng sản Đông Dương
#     New entity: Hội nghị toàn quốc của Đảng Cộng sản Đông Dương (Hội nghị)
#     Merged entity: Việt Minh
#     Merged entity: Uỷ ban Dân tộc giải phóng Việt Nam
#     Merged entity: Hồ Chí Minh
#     Merged entity: Tuyên ngôn Độc lập
#     Merged entity: Việt Nam Dân chủ Cộng hòa
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Pháp
#
# [Progress: 175/189 windows]
#   Processing window 16/21 of current file
#   [Request #175] Chủ đề 6 - Bài 16 - Window 16
#   [Request #175] Completed - Extracted 5 entities
#     Merged entity: Hồ Chí Minh
#     New entity: Nha Bình dân học vụ (Tổ chức)
#     New entity: Quỹ Độc lập (Tổ chức)
#     New entity: Tuần lễ vàng (Sự kiện)
#     New entity: 5 – 1 – 1946 (Khái niệm)
#
# [Progress: 176/189 windows]
#   Processing window 17/21 of current file
#   [Request #176] Chủ đề 6 - Bài 16 - Window 17
#   [Request #176] Completed - Extracted 8 entities
#     Merged entity: Chủ tịch Hồ Chí Minh
#     Merged entity: Cách mạng tháng Tám
#     Merged entity: Liên hợp quốc
#     Merged entity: Trung Hoa Dân quốc
#     Merged entity: Pháp
#     Merged entity: Hiệp ước Hoa – Pháp
#     Merged entity: Việt Nam Dân chủ Cộng hoà
#     Merged entity: Hiệp định Sơ bộ
#
# [Progress: 177/189 windows]
#   Processing window 18/21 of current file
#   [Request #177] Chủ đề 6 - Bài 16 - Window 18
#   [Request #177] Completed - Extracted 5 entities
#     Merged entity: Hiệp định Sơ bộ
#     Merged entity: Hồ Chí Minh
#     Merged entity: Pháp
#     Merged entity: Việt Nam
#     New entity: Tạm ước (Văn kiện/Hiệp định)
#
# [Progress: 178/189 windows]
#   Processing window 19/21 of current file
#   [Request #178] Chủ đề 6 - Bài 16 - Window 19
#   [Request #178] Completed - Extracted 9 entities
#     Merged entity: Hồ Chí Minh
#     Merged entity: Lời kêu gọi toàn quốc kháng chiến
#     Merged entity: Trung ương Đảng
#     New entity: Chính phủ (Tổ chức)
#     Merged entity: Việt Nam
#     Merged entity: Pháp
#     Merged entity: Đảng Lao động Việt Nam
#     New entity: Đại hội đại biểu lần thứ II của Đảng Lao động Việt Nam (Hội nghị)
#     New entity: chiến dịch quân sự (Chiến lược/Chủ trương)
#
# [Progress: 179/189 windows]
#   Processing window 20/21 of current file
#   [Request #179] Chủ đề 6 - Bài 16 - Window 20
#   [Request #179] Completed - Extracted 9 entities
#     Merged entity: Hồ Chí Minh
#     Merged entity: Đại hội đại biểu toàn quốc lần thứ III của Đảng Lao động Việt Nam
#     Merged entity: miền Bắc
#     Merged entity: miền Nam
#     New entity: giặc Mỹ xâm lược (Khái niệm)
#     New entity: Hội nghị lần thứ 15 Ban Chấp hành Trung ương Đảng Lao động Việt Nam (Hội nghị)
#     New entity: đế quốc Mỹ (Khái niệm)
#     New entity: quân đồng minh (Khái niệm)
#     New entity: quân Mỹ xâm lược (Khái niệm)
#
# [Progress: 180/189 windows]
#   Processing window 21/21 of current file
#   [Request #180] Chủ đề 6 - Bài 16 - Window 21
#   [Request #180] Completed - Extracted 7 entities
#     Merged entity: Hồ Chí Minh
#     Merged entity: Việt Nam
#     Merged entity: Đảng
#     New entity: đế quốc Mỹ (Quốc gia)
#     Merged entity: Liên Xô
#     Merged entity: Trung Quốc
#     New entity: cuộc kháng chiến chống thực dân Pháp (Sự kiện)
#
# Processing SGK/Nguồn/Chủ đề 6/Bài 17.txt...
#
# [Progress: 181/189 windows]
#   Processing window 1/9 of current file
#   [Request #181] Chủ đề 6 - Bài 17 - Window 1
#   [Request #181] Completed - Extracted 4 entities
#     New entity: UNESCO (Tổ chức)
#     Merged entity: Liên hợp quốc
#     Merged entity: Paris
#     Merged entity: Hồ Chí Minh
#
# [Progress: 182/189 windows]
#   Processing window 2/9 of current file
#   [Request #182] Chủ đề 6 - Bài 17 - Window 2
#   [Request #182] Completed - Extracted 16 entities
#     Merged entity: Hồ Chí Minh
#     Merged entity: Việt Nam
#     Merged entity: Lào
#     Merged entity: Phi-líp-pin
#     Merged entity: Thái Lan
#     Merged entity: Xin-ga-po
#     Merged entity: Ấn Độ
#     Merged entity: Mông Cổ
#     New entity: Hung-ga-ri (Quốc gia)
#     Merged entity: Nga
#     Merged entity: Pháp
#     New entity: Ác-hen-ti-na (Quốc gia)
#     New entity: Chi-lê (Quốc gia)
#     Merged entity: Cu-ba
#     New entity: Mê-hi-cô (Quốc gia)
#     New entity: Pa-na-ma (Quốc gia)
#
# [Progress: 183/189 windows]
#   Processing window 3/9 of current file
#   [Request #183] Chủ đề 6 - Bài 17 - Window 3
#   [Request #183] Completed - Extracted 3 entities
#     Merged entity: Hồ Chí Minh
#     New entity: Ô-xíp Man-den-xtam (Nhân Vật)
#     New entity: tạp chí Ngọn lửa nhỏ (Tổ chức)
#
# [Progress: 184/189 windows]
#   Processing window 4/9 of current file
#   [Request #184] Chủ đề 6 - Bài 17 - Window 4
#   [Request #184] Completed - Extracted 8 entities
#     Merged entity: Hồ Chí Minh
#     New entity: Khách sạn Ca-tơn (Địa điểm)
#     New entity: Nhà số 9, Thủ đô Pa-ri (Địa điểm)
#     New entity: Khu di tích Hồ Chí Minh tại Liễu Châu, Quảng Tây (Địa điểm)
#     Merged entity: Việt Nam
#     Merged entity: Anh
#     Merged entity: Pháp
#     Merged entity: Trung Quốc
#
# [Progress: 185/189 windows]
#   Processing window 5/9 of current file
#   [Request #185] Chủ đề 6 - Bài 17 - Window 5
#   [Request #185] Completed - Extracted 3 entities
#     Merged entity: Chủ tịch Hồ Chí Minh
#     New entity: nhà tù Côn Đảo (Địa điểm)
#     New entity: Đại sứ quán Pháp tại Việt Nam (Tổ chức)
#
# [Progress: 186/189 windows]
#   Processing window 6/9 of current file
#   [Request #186] Chủ đề 6 - Bài 17 - Window 6
#   [Request #186] Completed - Extracted 6 entities
#     Merged entity: Chủ tịch Hồ Chí Minh
#     New entity: Lăng Chủ tịch Hồ Chí Minh (Công trình)
#     New entity: Bảo tàng Hồ Chí Minh (Công trình)
#     Merged entity: cuộc kháng chiến chống Mỹ, cứu nước
#     New entity: tuyến đường chỉ viện chiến lược trên biển mang tên Chủ tịch Hồ Chí Minh (Chiến lược/Chủ trương)
#     New entity: Đại thắng Xuân năm 1975 (Sự kiện)
#
# [Progress: 187/189 windows]
#   Processing window 7/9 of current file
#   [Request #187] Chủ đề 6 - Bài 17 - Window 7
#   [Request #187] Completed - Extracted 4 entities
#     Merged entity: Quốc hội khoá VI
#     Merged entity: Chủ tịch Hồ Chí Minh
#     Merged entity: Sài Gòn – Gia Định
#
# [Progress: 188/189 windows]
#   Processing window 8/9 of current file
#   [Request #188] Chủ đề 6 - Bài 17 - Window 8
#   [Request #188] Completed - Extracted 3 entities
#     Merged entity: Hồ Chí Minh
#     Merged entity: Việt Bắc
#     Merged entity: Việt Nam
#
# [Progress: 189/189 windows]
#   Processing window 9/9 of current file
#   [Request #189] Chủ đề 6 - Bài 17 - Window 9
#   [Request #189] Completed - Extracted 6 entities
#     New entity: Bộ Chính trị Đảng Cộng sản Việt Nam khoá X (Tổ chức)
#     New entity: Chỉ thị 06-CT/TW (Văn kiện/Hiệp định)
#     Merged entity: Hồ Chí Minh
#     Merged entity: Chỉ thị 05-CT/TW
#     Merged entity: Việt Nam
#
# === REQUEST STATISTICS ===
# Total API Requests: 189
# Successful: 189 (100.0%)
# Failed: 0
# Total Processing Time: 1973.35s
# Average per Request: 10.44s
# Total Entities Extracted: 1162
# Total Entities Processed: 1045
# Final Unique Entities: 490
# Statistics saved to: entities/request_statistics_20251202_171911.json
#
# === REQUESTS BY FILE ===
# Bài 1.txt: 10 requests, 35 entities
# Bài 2.txt: 10 requests, 73 entities
# Bài 3.txt: 5 requests, 19 entities
# Bài 4.txt: 6 requests, 33 entities
# Bài 5.txt: 8 requests, 24 entities
# Bài 6.txt: 9 requests, 75 entities
# Bài 7.txt: 17 requests, 108 entities
# Bài 8.txt: 21 requests, 134 entities
# Bài 9.txt: 14 requests, 55 entities
# Bài 10.txt: 8 requests, 25 entities
# Bài 11.txt: 15 requests, 27 entities
# Bài 12.txt: 8 requests, 62 entities
# Bài 13.txt: 7 requests, 44 entities
# Bài 14.txt: 8 requests, 52 entities
# Bài 15.txt: 13 requests, 93 entities
# Bài 16.txt: 21 requests, 133 entities
# Bài 17.txt: 9 requests, 53 entities
#
# ============================================================
# === EXTRACTION SUMMARY ===
# {
#   "Sự kiện": 40,
#   "Khái niệm": 21,
#   "Tổ chức": 112,
#   "Quốc gia": 40,
#   "Văn kiện/Hiệp định": 45,
#   "Hội nghị": 26,
#   "Chiến lược/Chủ trương": 40,
#   "Địa điểm": 118,
#   "Công trình": 6,
#   "Nhân Vật": 25,
#   "Chiến dịch/Trận đánh": 17
# }
# Total unique entities: 490
# Entities saved to: entities/entities_20251202_171911.json
# ============================================================
# Entity extraction completed.
